# %%
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

from ES import ES_mu_lambda
from functions import (griewank, rastrigin, sphere, dp, schwefel)
from utils import (plot_hist, plot_one, run_multiproc_hist)

# %%
default_kwargs = {
    'population_evaluation': griewank,
    'individual_size': 80,
    'iterations': 2000,
    'plus': True,
    'Mu': 400,
    'Lambda': 1600,
    'K': 0.75,
    'domain': (-500,500),
    'verbose': False,
}

# %%
instance_kwargs = { 
    'population_evaluation': dp,
    'individual_size': 200,
    'domain': (-10, 10),
    'iterations': 50,
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 39.6 s, sys: 1min 27s, total: 2min 6s
# Wall time: 16.5 s

# %%
instance_kwargs = { 
        'population_evaluation': sphere,
        'individual_size': 70,
        'domain': (-5.12, 5.12),
        'iterations': 30
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# 8
# [104.15443539758859, 104.15443539758859, 104.15443539758859, 104.15443539758859, 104.15443539758859, 104.15443539758859, 104.15443539758859, 104.15443539758859]
# CPU times: user 240 ms, sys: 23.5 ms, total: 263 ms
# Wall time: 1.26 s

# %%
instance_kwargs = {
        'population_evaluation': griewank,
        'individual_size': 80,
        'domain': (-500, 500),
        'iterations':30
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# 8
# [481.85988801980551, 481.85988801980551, 481.85988801980551, 481.85988801980551, 481.85988801980551, 481.85988801980551, 481.85988801980551, 481.85988801980551]
# CPU times: user 281 ms, sys: 21.3 ms, total: 302 ms
# Wall time: 1.9 s

# %%
instance_kwargs = { 
        'population_evaluation': rastrigin,
        'individual_size': 40,
        'domain': (-5.12, 5.12),
        'K': 0.65,
        'iterations': 4000,
        
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 397 ms, sys: 28.1 ms, total: 425 ms
# Wall time: 1min 38s

# %%
instance_kwargs = { 
        'population_evaluation': schwefel,
        'individual_size': 40,
        'domain': (-500, 500),
        'K': 0.65,
        'iterations': 4000,
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 370 ms, sys: 82.7 ms, total: 452 ms
# Wall time: 1min 38s
