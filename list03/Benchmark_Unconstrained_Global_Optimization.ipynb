# %%
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

from ES import ES_mu_lambda
from functions import (griewank, rastrigin, sphere, dp, schwefel)
from utils import (plot_hist, plot_one, run_multiproc_hist)

# %%
default_kwargs = {
    'population_evaluation': griewank,
    'individual_size': 80,
    'iterations': 2000,
    'plus': True,
    'Mu': 400,
    'Lambda': 1600,
    'K': 0.75,
    'domain': (-500,500),
    'verbose': False,
}

# %%
instance_kwargs = { 
    'population_evaluation': dp,
    'individual_size': 200,
    'domain': (-10, 10),
    'iterations': 2000,
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 586 ms, sys: 130 ms, total: 716 ms
# Wall time: 3min 27s

# %%
instance_kwargs = { 
        'population_evaluation': sphere,
        'individual_size': 100,
        'domain': (-5.12, 5.12),
        'iterations': 600
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 251 ms, sys: 50.9 ms, total: 301 ms
# Wall time: 27.3 s

# %%
instance_kwargs = {
        'population_evaluation': griewank,
        'individual_size': 80,
        'domain': (-500, 500),
        'iterations':1000
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 301 ms, sys: 47.9 ms, total: 349 ms
# Wall time: 48.3 s

# %%
instance_kwargs = { 
        'population_evaluation': rastrigin,
        'individual_size': 60,
        'domain': (-5.12, 5.12),
        'K': 0.65,
        'iterations': 4000,
        'sigmas_upper_bound_coefficient': 5,
        'Mu': 300,
        'Lambda': 300 * 6,
        
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 422 ms, sys: 76 ms, total: 498 ms
# Wall time: 2min 44s

# %%
instance_kwargs = { 
        'population_evaluation': schwefel,
        'individual_size': 2,
        'domain': (-500, 500),
        'K': 0.65,
        'iterations': 20,
        'sigmas_upper_bound_coefficient': 0.55,
}

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs})
# Out:
# CPU times: user 291 ms, sys: 12.2 ms, total: 303 ms
# Wall time: 401 ms
