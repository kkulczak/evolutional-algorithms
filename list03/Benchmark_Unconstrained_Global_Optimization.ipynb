# %%
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

from ES import ES_mu_lambda
from functions import (griewank, rastrigin, sphere, dp, schwefel)
from utils import (plot_hist, plot_one, run_multiproc_hist)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
default_kwargs = {
    'population_evaluation': griewank,
    'individual_size': 80,
    'iterations': 2000,
    'plus': True,
    'Mu': 400,
    'Lambda': 1600,
    'K': 0.75,
    'domain': (-500,500),
    'verbose': False,
}

# %%
instance_kwargs = { 
    'population_evaluation': dp,
    'individual_size': 200,
    'domain': (-10, 10),
    'iterations': 500,
}

# %%
# plot_one(ES_mu_lambda(**{**default_kwargs, **instance_kwargs}))
run_multiproc_hist({**default_kwargs, **instance_kwargs})

# %%
# %%time
run_multiproc_hist({**default_kwargs, **instance_kwargs}, 2)
# Out:
# CPU times: user 310 ms, sys: 24 ms, total: 334 ms
# Wall time: 1min 14s

# %%
instance_kwargs = { 
        'population_evaluation': sphere,
        'individual_size': 60,
        'domain': (-5.12, 5.12)
}

# %%
instance_kwargs = {
        'population_evaluation': griewank,
        'individual_size': 80,
        'domain': (-500, 500)
}

# %%
instance_kwargs = { 
        'population_evaluation': rastrigin,
        'individual_size': 60,
        'domain': (-5.12, 5.12)
}

# %%
instance_kwargs = { 
        'population_evaluation': schwefel,
        'individual_size': 60,
        'domain': (-500, 500)
}
