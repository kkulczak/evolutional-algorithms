# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from SGA import SGA
from PMX import PMX
from OX import OX
from LOX import LOX
from utils import *
from data import berlin52
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data, n = berlin52()
population_size = 500
chromosome_length = n
number_of_offspring = population_size
crossover_probability = 0.95
mutation_probability = 0.25
number_of_iterations = 250

for op in [PMX, OX, LOX]:
    kwargs = {  
        'population_size':population_size,
        'chromosome_length': n,
        'number_of_offspring':number_of_offspring,
        'crossover_probability':crossover_probability,
        'mutation_probability':mutation_probability,
        'number_of_iterations':number_of_iterations,
        'tsp_objective_function':lambda x: tsp_objective_function_2(x, data, n),
        'operator':op,
        'mutation':reverse_sequence_mutation,
    }
    plot_scores(title=op.__name__, **kwargs)
# Out:
# PMX 8447.188999488615 18.948503017425537
# OX 8394.457648990105 21.12356925010681
# LOX 8361.626079089521 18.715604066848755
