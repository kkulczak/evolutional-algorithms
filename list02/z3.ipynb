# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from SGA import SGA
from PMX import PMX
from OX import OX
from LOX import LOX
from MutationLocalSearch import mutation_local_search
from utils import *
from data import berlin52
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data, n = berlin52()
population_size = 500
chromosome_length = n
number_of_offspring = population_size
crossover_probability = 0.95
mutation_probability = 0.25
number_of_iterations = 250

# for i in [0.01, 0.1, 0.8]
kwargs = {  
    'population_size':population_size,
    'chromosome_length': n,
    'number_of_offspring':number_of_offspring,
    'crossover_probability':crossover_probability,
    'mutation_probability':mutation_probability,
    'number_of_iterations':number_of_iterations,
    'tsp_objective_function':lambda x: tsp_objective_function_2(x, data, n),
    'operator':OX,
    'mutation':reverse_sequence_mutation,
    'local_search_mut_propability':0.0001,
    'local_search_mut_K':3,
}
plot_scores(title='', **kwargs)
# Out:
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
#  7914.01375179 42.515393018722534

# %%
plot_scores(title='', **kwargs)
# Out:
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
#  8315.89276774 80.99924898147583

# %%
plot_scores(title='', **kwargs)
# Out:
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
#  7981.69351419 45.74240779876709

# %%
plot_scores(title='', **kwargs)
# Out:
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
# PING
#  8357.75260415 47.84981870651245
